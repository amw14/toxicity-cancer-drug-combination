# %% [markdown]
# # Check on DrugBank DDI vs DDInter DDI #

# %%
import pandas as pd
from preprocessing_functions import *

# %%
# Assumes that the following files are in the data_processed folder:
drugbankddi_known_syntox = pd.read_csv('data_processed/drugbank_syntox_known.csv')
ddinter_known_syntox = pd.read_csv('data_processed/ddinter_syntox_known.csv')

# %%
# How many of the drugcomb-ddinter intersection pairs overlap with the drugcomb-ddinter intersection pairs?
num_agreeing_pairs = 0
ddinter_pairs_not_drugbank = set()
drugbank_pairs_not_ddinter = set()
disagreeing_pairs = set() # drug 1, drug 2, drugbank_toxicity, ddinter_toxicity

# create a set of all the drug pairs in the drugbank data (flipped and unflipped)
drugbank_pairs = {}
for index, row in drugbankddi_known_syntox.iterrows():
    drug1 = row['drug_row']
    drug2 = row['drug_col']
    drugbank_tox = row['toxicity_category']
    if (drug1, drug2) not in drugbank_pairs and (drug2, drug1) not in drugbank_pairs:
        drugbank_pairs[(drug1, drug2)] = drugbank_tox
        drugbank_pairs[(drug2, drug1)] = drugbank_tox

ddinter_pairs = {}
for index, row in ddinter_known_syntox.iterrows():
    drug1 = row['drug_row']
    drug2 = row['drug_col']
    ddinter_tox = row['toxicity_category']
    if (drug1, drug2) in drugbank_pairs or (drug2, drug1) in drugbank_pairs:
        if drugbank_pairs[(drug1, drug2)] != ddinter_tox:
            disagreeing_pairs.add((drug1, drug2, drugbank_pairs[(drug1, drug2)], ddinter_tox))
        else:
            num_agreeing_pairs += 1
    else:
        ddinter_pairs_not_drugbank.add((drug1, drug2))
    
    if (drug1, drug2) not in ddinter_pairs and (drug2, drug1) not in ddinter_pairs:
        ddinter_pairs[(drug1, drug2)] = ddinter_tox
        ddinter_pairs[(drug2, drug1)] = ddinter_tox

for index, row in drugbankddi_known_syntox.iterrows():
    drug1 = row['drug_row']
    drug2 = row['drug_col']
    if (drug1, drug2) not in ddinter_pairs and (drug2, drug1) not in ddinter_pairs:
        drugbank_pairs_not_ddinter.add((drug1, drug2))

print('Number of drug pairs in the intersection of drugcomb and drugbank that agree on toxicity category:', num_agreeing_pairs)
print('Number of drug pairs in the intersection of drugcomb and drugbank that disagree on toxicity category:', len(disagreeing_pairs))
print('Number of drug pairs in the intersection of drugcomb and drugbank that are not in the ddinter data:', len(drugbank_pairs_not_ddinter))
print('Number of drug pairs in the intersection of drugcomb and ddinter that are not in the drugbank data:', len(ddinter_pairs_not_drugbank))
print(disagreeing_pairs) # There are pairs that disagree on toxicity category between DrugBank and DDInter
# Out:
# Number of drug pairs in the intersection of drugcomb and drugbank that agree on toxicity category: 9466
# Number of drug pairs in the intersection of drugcomb and drugbank that disagree on toxicity category: 2141
# Number of drug pairs in the intersection of drugcomb and drugbank that are not in the ddinter data: 66277
# Number of drug pairs in the intersection of drugcomb and ddinter that are not in the drugbank data: 0
# {('leflunomide', 'gefitinib', 'Moderate', 'Major'), ('zafirlukast', 'clofarabine', 'Unknown', 'Moderate'), ('dronedarone', 'irinotecan', 'Major', 'Moderate'), ('leflunomide', 'hydralazine', 'Unknown', 'Moderate'), ('orlistat', 'amprenavir', 'Unknown', 'Moderate'), ('tinidazole', 'bortezomib', 'Unknown', 'Moderate'), ('digitoxin', 'tetracycline', 'Major', 'Moderate'), ('lenalidomide', 'methotrexate', 'Major', 'Moderate'), ('mitotane', 'amprenavir', 'Major', 'Moderate'), ('tacrolimus', 'pazopanib', 'Moderate', 'Major'), ('hydroxyurea', 'vinblastine', 'Major', 'Moderate'), ('sunitinib', 'sulfinpyrazone', 'Major', 'Moderate'), ('gemcitabine', 'methotrexate', 'Major', 'Moderate'), ('loperamide', 'cisapride', 'Major', 'Moderate'), ('etoposide', 'fingolimod', 'Moderate', 'Major'), ('mitoxantrone', 'bleomycin', 'Major', 'Moderate'), ('clofarabine', 'sorafenib', 'Major', 'Moderate'), ('paclitaxel', 'niraparib', 'Unknown', 'Moderate'), ('sildenafil', 'diazoxide', 'Minor', 'Moderate'), ('topiramate', 'hydroxychloroquine', 'Major', 'Moderate'), ('amoxapine', 'flutamide', 'Unknown', 'Moderate'), ('nabilone', 'bumetanide', 'Minor', 'Moderate'), ('duloxetine', 'ruxolitinib', 'Minor', 'Moderate'), ('topotecan', 'ixazomib', 'Minor', 'Moderate'), ('chlorambucil', 'imatinib', 'Major', 'Moderate'), ('naltrexone', 'zileuton', 'Unknown', 'Moderate'), ('naltrexone', 'meclofenamic acid', 'Unknown', 'Moderate'), ('dasatinib', 'tamoxifen', 'Major', 'Moderate'), ('dacarbazine', 'imatinib', 'Major', 'Moderate'), ('cinacalcet', 'bortezomib', 'Major', 'Moderate'), ('tolvaptan', 'nitisinone', 'Unknown', 'Moderate'), ('amprenavir', 'acetohexamide', 'Minor', 'Moderate'), ('bosentan', 'nitisinone', 'Unknown', 'Moderate'), ('disulfiram', 'tranylcypromine', 'Unknown', 'Moderate'), ('vinblastine', 'metronidazole', 'Major', 'Moderate'), ('lumefantrine', 'ranolazine', 'Moderate', 'Major'), ('halofantrine', 'isoniazid', 'Moderate', 'Major'), ('tamoxifen', 'triflupromazine', 'Unknown', 'Moderate'), ('cinacalcet', 'tetrabenazine', 'Moderate', 'Major'), ('naltrexone', 'riluzole', 'Unknown', 'Moderate'), ('axitinib', 'lapatinib', 'Major', 'Moderate'), ('thalidomide', 'mefloquine', 'Unknown', 'Moderate'), ('mitoxantrone', 'nilotinib', 'Major', 'Moderate'), ('ivermectin', 'efavirenz', 'Major', 'Moderate'), ('pazopanib', 'primidone', 'Major', 'Moderate'), ('mitotane', 'aprepitant', 'Major', 'Moderate'), ('chlorambucil', 'ganciclovir', 'Unknown', 'Moderate'), ('teriflunomide', 'methyldopa', 'Unknown', 'Major'), ('rufinamide', 'nitisinone', 'Unknown', 'Moderate'), ('azatadine', 'fluvoxamine', 'Unknown', 'Moderate'), ('gefitinib', 'itraconazole', 'Major', 'Moderate'), ('fedratinib', 'ruxolitinib', 'Moderate', 'Minor'), ('imatinib', 'leflunomide', 'Moderate', 'Major'), ('saxagliptin', 'sulfinpyrazone', 'Unknown', 'Moderate'), ('chloroquine', 'docetaxel', 'Major', 'Moderate'), ('ibutilide', 'thalidomide', 'Unknown', 'Moderate'), ('palonosetron', 'thalidomide', 'Major', 'Moderate'), ('procarbazine', 'enoxacin', 'Unknown', 'Minor'), ('sparfloxacin', 'temozolomide', 'Unknown', 'Minor'), ('niraparib', 'vincristine', 'Unknown', 'Moderate'), ('clofarabine', 'bortezomib', 'Major', 'Moderate'), ('ruxolitinib', 'temozolomide', 'Major', 'Moderate'), ('metformin', 'vorinostat', 'Minor', 'Moderate'), ('thalidomide', 'doxorubicin', 'Moderate', 'Major'), ('ramelteon', 'azatadine', 'Unknown', 'Moderate'), ('citalopram', 'ruxolitinib', 'Major', 'Moderate'), ('metformin', 'amprenavir', 'Unknown', 'Moderate'), ('loperamide', 'halofantrine', 'Major', 'Moderate'), ('docetaxel', 'busulfan', 'Major', 'Moderate'), ('bosentan', 'clofarabine', 'Minor', 'Moderate'), ('azatadine', 'chlorzoxazone', 'Unknown', 'Moderate'), ('risperidone', 'thalidomide', 'Major', 'Moderate'), ('spironolactone', 'irinotecan', 'Unknown', 'Moderate'), ('tiagabine', 'tacrolimus', 'Unknown', 'Moderate'), ('bortezomib', 'saxagliptin', 'Unknown', 'Moderate'), ('mitotane', 'levonorgestrel', 'Major', 'Moderate'), ('risperidone', 'ch ...

# %%
print("Number of disagreeing pairs:", len(disagreeing_pairs))
# Out:
# Number of disagreeing pairs: 2141
