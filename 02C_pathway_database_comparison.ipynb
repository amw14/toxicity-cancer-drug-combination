# %%
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
# Load statistical summeries per database
ddinter_pathway_df = pd.read_csv('results/pathway_syntox_analysis/ddinter_synergy_toxicity_statistical_summary.csv')
drugbank_pathway_df = pd.read_csv('results/pathway_syntox_analysis/drugbank_synergy_toxicity_statistical_summary.csv')

# Combine both dataframes
ddinter_pathway_df["Database"] = "DDInter"
drugbank_pathway_df["Database"] = "DrugBank"
combined_pathway_df = pd.concat([ddinter_pathway_df, drugbank_pathway_df], ignore_index=True)

# %%
# Define expected metrics and databases for looping
metrics = [
    'Drug Target Jaccard Similarity', 
    'Lowest Reactome Pathways Jaccard Similarity', 
    'All Reactome Pathways Jaccard Similarity'
    ]

databases = ['DrugBank', 'DDInter'] 

# Retrieve all necessary data for one test/database/metric combination 
def get_stats_data(df, metric, db, test_type, comparison=''):
    """
    Filters the DataFrame for a specific test result and extracts the Statistic, 
    P-value, Effect Size, and Effect Symbol.
    """
    
    # Determine which P-value column to use and the Effect Size Symbol
    if test_type == 'Kruskal-Wallis':
        p_col = 'P_value'
        e_symbol = '\\eta^2'
    elif test_type == 'Dunn Post-Hoc':
        p_col = 'P_value_Corrected'
        e_symbol = '\\delta'
    elif test_type == 'Jonckheere-Terpstra':
        p_col = 'P_value'
        e_symbol = 'r'
    else:
        return np.nan, np.nan, np.nan, ''

    # Filter the DataFrame
    print(df[(df['Synergy_Score'] == metric) &
        (df['Database'] == db)].head(3))
    result_row = df[
        (df['Synergy_Score'] == metric) &
        (df['Database'] == db) &
        (df['Test_Type'] == test_type) &
        (df['Comparison'] == comparison)
    ]
    print(result_row )
    if result_row.empty:
        # Return standard NaN placeholders if no data found
        return np.nan, np.nan, np.nan, e_symbol
    
    # Extract values
    row = result_row.iloc[0]
    
    # Test Statistic (assumed to be H for KW, Z for JT, and NaN/blank for Dunn)
    stat = row.get('Test_Statistic', np.nan)
    
    p = row.get(p_col, np.nan)
    e = row.get('Effect_Size_Value', np.nan)

    return stat, p, e, e_symbol


# Function to format the P-value and Effect Size for LaTeX
def format_p_effect(p_value, effect_size, effect_symbol):
    """Formats P-value and Effect Size into the string P-value (Effect Size Symbol = Value)."""
    
    # Check for missing data
    if pd.isna(p_value) or pd.isna(effect_size):
         return '-'
         
    # P-value Formatting
    if p_value >= 0.05:
        # For non-significant P-values: e.g., 0.10, >0.99. All must be in math mode.
        p_str = "${:.3f}$".format(p_value)
    else:
        # Handle P-value of zero or near-zero
        if p_value <= 1e-300: # Use a safe threshold
            p_str = "${:.3f}$".format(p_value)
        else:
            # For significant P-values: use scientific notation. All must be in math mode.
            exponent = int(np.floor(np.log10(p_value)))
            mantissa = p_value / 10**exponent
            p_str = "${:.3f} \\times 10^{{{:d}}}$".format(mantissa, exponent)
    
    # Effect Size Formatting
    # Ensure correct sign formatting for the effect size
    sign = "+" if effect_size >= 0 else ""
    effect_str = "{}{:.3f}".format(sign, effect_size)
    
    # Combine P-value and effect size with the correct symbol. All symbols and values must be in math mode.
    return f"{p_str} ($\\mathbf{{{effect_symbol}}}={effect_str}$)"

# --- Function to format the Test Statistic ---
def format_statistic(stat):
    """Formats the Test Statistic (H or Z) into a clean LaTeX string."""
    if not isinstance(stat, str):
        return '-'
    
    stat_type = str(stat.split('=')[0])
    stat_val = float(stat.split('=')[1])

    abs_stat = abs(stat_val)
    if abs_stat >= 10:
        exponent = int(np.floor(np.log10(abs_stat)))
        mantissa = abs_stat / 10**exponent
        sign = "-" if stat_val < 0 else ""
        return f"${sign}{mantissa:.3f} \\times 10^{{{exponent:d}}}$"
    else:
        # Fixed decimal for smaller stats, enclosed in math mode
        return "${:.3f}$".format(stat_val)

# Generate LaTex Table
def generate_latex_table_from_df(df, metrics_list, databases_list):
    """Generates the final LaTeX code string for the summary table based on the DataFrame."""
    
    # Define the 6 Test rows for each Synergy Score, matching the DataFrame columns
    test_rows_map = [
        ('Kruskal-Wallis', 'Kruskal-Wallis', 'All Groups'),
        ('Dunn: Major/Minor', 'Dunn Post-Hoc', 'Major vs Minor'),
        ('Dunn: Major/Moderate', 'Dunn Post-Hoc', 'Major vs Moderate'),
        ('Dunn: Moderate/Minor', 'Dunn Post-Hoc', 'Moderate vs Minor'),
        ('Jonckheere-Terpstra: Increasing Toxicity', 'Jonckheere-Terpstra', 'Increasing Trend (Minor->Major)'),
        ('Jonckheere-Terpstra: Decreasing Toxicity', 'Jonckheere-Terpstra', 'Decreasing Trend (Major->Minor)'),
    ]
    
    # Start of LaTeX Table Code (Using your requested structure)
    latex_code = [
        "\\begin{table}[htbp]",
        "\\centering",
        "\\small", # Requested formatting
        "\\caption{\\textbf{Drug target and pathway overlap toxicity analysis}. Results for statistical analysis of drug targets and pathway overlap correlated with toxicity categories. Each section refers to a different Jaccard Similarity metric. The first section computed the overlap between the sets of drug targets in a given drug combination, the second the sets of pathways, and the third the sets of pathways when restricted to the lowest level of Reactome. The results for the Kruskal-Wallis, Dunn with Bonferroni correction, and Jonckheere-Terpstra tests are included for both the DrugBank and DDInter datasets. The Jonckheere-Terpestra Increasing Toxicity test assesses whether the distribution of the Jaccard Similarity increases when toxicity categories become more severe, while the Jonckheere-Terpstra Decreasing Toxicity test evaluates if the Jaccard Similarity distributions increase when the toxicity categories decrease in severity.}",
        "\\label{tab:s_targ_tox}",
        "\\vspace{0.5em}", # Requested formatting
        "\\resizebox{\\textwidth}{!}{", 
        "\\scriptsize", # Use smallest common font size
        "\\begin{tabular}{ll|rr|rr}", # l=Score, l=Test, r r = DrugBank, r r = DDInter
        "\\toprule",
    ]
    
    # Header Rows
    header_row_1 = ["\\textbf{Overlap Metric}", "\\textbf{Test}", 
                    "\\multicolumn{2}{c|}{\\textbf{DrugBank}}", 
                    "\\multicolumn{2}{c}{\\textbf{DDInter}}"]
    latex_code.append(" & ".join(header_row_1) + " \\\\")
    
    # P-value column now includes Effect Size
    header_row_2 = ["\\textbf{Score}", "", "\\textbf{Test Statistic}", 
                    "\\textbf{P-value (Effect Size)}", 
                    "\\textbf{Test Statistic}", 
                    "\\textbf{P-value (Effect Size)}"]
    latex_code.append(" & ".join(header_row_2) + " \\\\")

    latex_code.append("\\midrule")
    
    # Data Rows 
    for i, metric in enumerate(metrics_list):
        # Escape underscores in synergy scores (e.g., S\_max) for text mode
        escaped_metric = metric.replace('_', '\\_') 
        score_cell = f"\\multirow{{{len(test_rows_map)}}}{{*}}{{\\textbf{{{escaped_metric}}}}}"
        
        for j, (display_name, test_type, comparison_col) in enumerate(test_rows_map):
            row_data = {}
            is_statistic_required = test_type == 'Kruskal-Wallis' or test_type == 'Jonckheere-Terpstra'

            for db in databases_list: # Loop over ['DrugBank', 'DDInter']
                # 1. Get Data
                stat, p, e, e_symbol = get_stats_data(df, metric, db, test_type, comparison_col)
                print(f"Retrived for {db}, {metric}, {test_type}, {comparison_col}: stat={stat}, p={p}, e={e}, e_symbol={e_symbol}")
                # 2. Format Strings
                stat_str = format_statistic(stat) if is_statistic_required else '-'
                p_e_str = format_p_effect(p, e, e_symbol)

                row_data[db] = {
                    'stat': stat_str,
                    'p_e': p_e_str
                }
            # 4. Construct Row
            row_cells = [
                score_cell if j == 0 else "", 
                display_name,
                row_data['DrugBank']['stat'],
                row_data['DrugBank']['p_e'],
                row_data['DDInter']['stat'],
                row_data['DDInter']['p_e']
            ]
            latex_code.append(" & ".join(row_cells) + " \\\\")

        # Add horizontal rule after each metric group, except the last one
        if i < len(metrics_list) - 1:
            latex_code.append("\\midrule")
            
    # --- Footer ---
    latex_code.append("\\bottomrule")
    latex_code.append("\\end{tabular}")
    latex_code.append("}") # Closing bracket for \resizebox
    latex_code.append("\\end{table}")
    
    return "\n".join(latex_code)

# Now generate the table
latex_output = generate_latex_table_from_df(combined_pathway_df, metrics, databases)

# Print the output to the console (standard behavior)
print(latex_output)

filename = "results/pathway_syntox_analysis/pathway_statistical_summary_table.tex"
with open(filename, 'w', encoding='utf-8') as f:
            f.write(latex_output)
print(f"Success! LaTeX table saved to {filename}")
print(latex_output)
# Out:
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score       Test_Type  Comparison Test_Statistic  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis  All Groups   H=1.5326e+02
#
#          P_value  P_value_Corrected Effect_Size_Type  Effect_Size_Value  \
# 18  5.253554e-34                NaN    Eta-Squared H           0.002443
#
#     Database
# 18  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=1.5326e+02, p=5.253553895891229e-34, e=0.0024432537306633, e_symbol=\eta^2
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score       Test_Type  Comparison Test_Statistic  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis  All Groups   H=1.5647e+02
#
#         P_value  P_value_Corrected Effect_Size_Type  Effect_Size_Value  \
# 0  1.052539e-34                NaN    Eta-Squared H           0.005384
#
#   Database
# 0  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=1.5647e+02, p=1.0525393822539299e-34, e=0.0053839374777624, e_symbol=\eta^2
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score      Test_Type      Comparison  \
# 19  Drug Target Jaccard Similarity  Dunn Post-Hoc  Major vs Minor
#
#    Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 19         Dunn Z      NaN       9.491539e-31    Cliff's Delta
#
#     Effect_Size_Value  Database
# 19           0.035961  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=9.491538890393464e-31, e=0.0359607275174889, e_symbol=\delta
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score      Test_Type      Comparison  \
# 1  Drug Target Jaccard Similarity  Dunn Post-Hoc  Major vs Minor
#
#   Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 1         Dunn Z      NaN       1.352075e-25    Cliff's Delta
#
#    Effect_Size_Value Database
# 1           0.110257  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=1.352075272331821e-25, e=0.1102574743908983, e_symbol=\delta
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score      Test_Type         Comparison  \
# 20  Drug Target Jaccard Similarity  Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 20         Dunn Z      NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 20           0.014351  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=2.6361575144541325e-11, e=0.0143506236538175, e_symbol=\delta
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score      Test_Type         Comparison  \
# 2  Drug Target Jaccard Similarity  Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 2         Dunn Z      NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 2           0.038952  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=9.079921242373742e-22, e=0.0389520193532065, e_symbol=\delta
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score      Test_Type         Comparison  \
# 21  Drug Target Jaccard Similarity  Dunn Post-Hoc  Moderate vs Minor
#
#    Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 21         Dunn Z      NaN       1.683787e-10    Cliff's Delta
#
#     Effect_Size_Value  Database
# 21           0.021996  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=1.6837868225290248e-10, e=0.0219961307197778, e_symbol=\delta
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score      Test_Type         Comparison  \
# 3  Drug Target Jaccard Similarity  Dunn Post-Hoc  Moderate vs Minor
#
#   Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 3         Dunn Z      NaN       5.719235e-12    Cliff's Delta
#
#    Effect_Size_Value Database
# 3           0.067074  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=5.719235344193383e-12, e=0.0670744629916341, e_symbol=\delta
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score            Test_Type  \
# 22  Drug Target Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic       P_value  \
# 22  Increasing Trend (Minor->Major)   Z=4.7818e+00  8.686941e-07
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 22                NaN                r           0.019092  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=4.7818e+00, p=8.686940817792532e-07, e=0.0190923779078144, e_symbol=r
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score            Test_Type  \
# 4  Drug Target Jaccard Similarity  Jonckheere-Terpstra
#
#                         Comparison Test_Statistic       P_value  \
# 4  Increasing Trend (Minor->Major)   Z=5.6787e+00  6.786590e-09
#
#    P_value_Corrected Effect_Size_Type  Effect_Size_Value Database
# 4                NaN                r            0.03331  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=5.6787e+00, p=6.786590178720075e-09, e=0.0333096688549261, e_symbol=r
#                      Synergy_Score       Test_Type         Comparison  \
# 18  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 19  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 20  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#    Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 18   H=1.5326e+02  5.253554e-34                NaN    Eta-Squared H
# 19         Dunn Z           NaN       9.491539e-31    Cliff's Delta
# 20         Dunn Z           NaN       2.636158e-11    Cliff's Delta
#
#     Effect_Size_Value  Database
# 18           0.002443  DrugBank
# 19           0.035961  DrugBank
# 20           0.014351  DrugBank
#                      Synergy_Score            Test_Type  \
# 23  Drug Target Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic   P_value  \
# 23  Decreasing Trend (Major->Minor)  Z=-4.7818e+00  0.999999
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 23                NaN                r          -0.019092  DrugBank
# Retrived for DrugBank, Drug Target Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-4.7818e+00, p=0.9999991313059182, e=-0.0190923779078144, e_symbol=r
#                     Synergy_Score       Test_Type         Comparison  \
# 0  Drug Target Jaccard Similarity  Kruskal-Wallis         All Groups
# 1  Drug Target Jaccard Similarity   Dunn Post-Hoc     Major vs Minor
# 2  Drug Target Jaccard Similarity   Dunn Post-Hoc  Major vs Moderate
#
#   Test_Statistic       P_value  P_value_Corrected Effect_Size_Type  \
# 0   H=1.5647e+02  1.052539e-34                NaN    Eta-Squared H
# 1         Dunn Z           NaN       1.352075e-25    Cliff's Delta
# 2         Dunn Z           NaN       9.079921e-22    Cliff's Delta
#
#    Effect_Size_Value Database
# 0           0.005384  DDInter
# 1           0.110257  DDInter
# 2           0.038952  DDInter
#                     Synergy_Score            Test_Type  \
# 5  Drug Target Jaccard Similarity  Jonckheere-Terpstra
#
#                         Comparison Test_Statistic  P_value  P_value_Corrected  \
# 5  Decreasing Trend (Major->Minor)  Z=-5.6787e+00      1.0                NaN
#
#   Effect_Size_Type  Effect_Size_Value Database
# 5                r           -0.03331  DDInter
# Retrived for DDInter, Drug Target Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-5.6787e+00, p=0.9999999932134098, e=-0.0333096688549261, e_symbol=r
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score       Test_Type  Comparison  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis  All Groups
#
#    Test_Statistic        P_value  P_value_Corrected Effect_Size_Type  \
# 24   H=1.0848e+03  2.789769e-236                NaN    Eta-Squared H
#
#     Effect_Size_Value  Database
# 24           0.017293  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=1.0848e+03, p=2.7897686830631307e-236, e=0.0172934820177433, e_symbol=\eta^2
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                  Synergy_Score       Test_Type  Comparison  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis  All Groups
#
#   Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 6   H=1.5841e+03      0.0                NaN    Eta-Squared H
#
#    Effect_Size_Value Database
# 6           0.054506  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=1.5841e+03, p=0.0, e=0.0545063013161198, e_symbol=\eta^2
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score      Test_Type  \
# 25  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#         Comparison Test_Statistic  P_value  P_value_Corrected  \
# 25  Major vs Minor         Dunn Z      NaN       9.491539e-31
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 25    Cliff's Delta           0.193367  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=9.491538890393464e-31, e=0.1933671294911328, e_symbol=\delta
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                  Synergy_Score      Test_Type      Comparison  \
# 7  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc  Major vs Minor
#
#   Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 7         Dunn Z      NaN       1.352075e-25    Cliff's Delta
#
#    Effect_Size_Value Database
# 7           0.080997  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=1.352075272331821e-25, e=0.0809974299228976, e_symbol=\delta
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score      Test_Type  \
# 26  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 26  Major vs Moderate         Dunn Z      NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 26    Cliff's Delta           0.097416  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=2.6361575144541325e-11, e=0.0974162991288315, e_symbol=\delta
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                  Synergy_Score      Test_Type  \
# 8  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 8    Cliff's Delta           0.286719  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=9.079921242373742e-22, e=0.2867192126608969, e_symbol=\delta
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score      Test_Type  \
# 27  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 27  Moderate vs Minor         Dunn Z      NaN       1.683787e-10
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 27    Cliff's Delta           0.085669  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=1.6837868225290248e-10, e=0.0856693633956146, e_symbol=\delta
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                  Synergy_Score      Test_Type  \
# 9  Lowest Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 9  Moderate vs Minor         Dunn Z      NaN       5.719235e-12
#
#   Effect_Size_Type  Effect_Size_Value Database
# 9    Cliff's Delta          -0.266337  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=5.719235344193383e-12, e=-0.2663368372351878, e_symbol=\delta
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score            Test_Type  \
# 28  Lowest Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 28  Increasing Trend (Minor->Major)   Z=2.7895e+01      0.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 28                NaN                r           0.111379  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=2.7895e+01, p=0.0, e=0.1113787730727144, e_symbol=r
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                   Synergy_Score            Test_Type  \
# 10  Lowest Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 10  Increasing Trend (Minor->Major)   Z=2.7099e+01      0.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value Database
# 10                NaN                r           0.158953  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=2.7099e+01, p=0.0, e=0.1589533497391165, e_symbol=r
#                                   Synergy_Score       Test_Type  \
# 24  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 25  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 26  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 24         All Groups   H=1.0848e+03  2.789769e-236                NaN
# 25     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 26  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 24    Eta-Squared H           0.017293  DrugBank
# 25    Cliff's Delta           0.193367  DrugBank
# 26    Cliff's Delta           0.097416  DrugBank
#                                   Synergy_Score            Test_Type  \
# 29  Lowest Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 29  Decreasing Trend (Major->Minor)  Z=-2.7895e+01      1.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 29                NaN                r          -0.111379  DrugBank
# Retrived for DrugBank, Lowest Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-2.7895e+01, p=1.0, e=-0.1113787730727144, e_symbol=r
#                                  Synergy_Score       Test_Type  \
# 6  Lowest Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 7  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 8  Lowest Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#           Comparison Test_Statistic  P_value  P_value_Corrected  \
# 6         All Groups   H=1.5841e+03      0.0                NaN
# 7     Major vs Minor         Dunn Z      NaN       1.352075e-25
# 8  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#   Effect_Size_Type  Effect_Size_Value Database
# 6    Eta-Squared H           0.054506  DDInter
# 7    Cliff's Delta           0.080997  DDInter
# 8    Cliff's Delta           0.286719  DDInter
#                                   Synergy_Score            Test_Type  \
# 11  Lowest Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 11  Decreasing Trend (Major->Minor)  Z=-2.7099e+01      1.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value Database
# 11                NaN                r          -0.158953  DDInter
# Retrived for DDInter, Lowest Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-2.7099e+01, p=1.0, e=-0.1589533497391165, e_symbol=r
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score       Test_Type  Comparison  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis  All Groups
#
#    Test_Statistic        P_value  P_value_Corrected Effect_Size_Type  \
# 30   H=1.0964e+03  8.281342e-239                NaN    Eta-Squared H
#
#     Effect_Size_Value  Database
# 30           0.017479  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=1.0964e+03, p=8.281341753052738e-239, e=0.0174790387623459, e_symbol=\eta^2
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score       Test_Type  Comparison  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis  All Groups
#
#    Test_Statistic        P_value  P_value_Corrected Effect_Size_Type  \
# 12   H=7.6788e+02  1.809712e-167                NaN    Eta-Squared H
#
#     Effect_Size_Value Database
# 12           0.026421  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Kruskal-Wallis, All Groups: stat=H=7.6788e+02, p=1.809711621964873e-167, e=0.026421122597275, e_symbol=\eta^2
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score      Test_Type      Comparison  \
# 31  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc  Major vs Minor
#
#    Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 31         Dunn Z      NaN       9.491539e-31    Cliff's Delta
#
#     Effect_Size_Value  Database
# 31           0.226887  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=9.491538890393464e-31, e=0.2268865466410468, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score      Test_Type      Comparison  \
# 13  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc  Major vs Minor
#
#    Test_Statistic  P_value  P_value_Corrected Effect_Size_Type  \
# 13         Dunn Z      NaN       1.352075e-25    Cliff's Delta
#
#     Effect_Size_Value Database
# 13           0.049278  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Minor: stat=Dunn Z, p=1.352075272331821e-25, e=0.0492781450110169, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score      Test_Type  \
# 32  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 32  Major vs Moderate         Dunn Z      NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 32    Cliff's Delta           0.108966  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=2.6361575144541325e-11, e=0.1089661676325684, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score      Test_Type  \
# 14  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 14  Major vs Moderate         Dunn Z      NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 14    Cliff's Delta           0.223512  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Major vs Moderate: stat=Dunn Z, p=9.079921242373742e-22, e=0.2235116354098451, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score      Test_Type  \
# 33  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 33  Moderate vs Minor         Dunn Z      NaN       1.683787e-10
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 33    Cliff's Delta           0.112281  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=1.6837868225290248e-10, e=0.1122808183861228, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score      Test_Type  \
# 15  All Reactome Pathways Jaccard Similarity  Dunn Post-Hoc
#
#            Comparison Test_Statistic  P_value  P_value_Corrected  \
# 15  Moderate vs Minor         Dunn Z      NaN       5.719235e-12
#
#    Effect_Size_Type  Effect_Size_Value Database
# 15    Cliff's Delta            -0.2257  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Dunn Post-Hoc, Moderate vs Minor: stat=Dunn Z, p=5.719235344193383e-12, e=-0.2257000636649252, e_symbol=\delta
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score            Test_Type  \
# 34  All Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 34  Increasing Trend (Minor->Major)   Z=3.2245e+01      0.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 34                NaN                r           0.128746  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=3.2245e+01, p=0.0, e=0.1287458580388428, e_symbol=r
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score            Test_Type  \
# 16  All Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 16  Increasing Trend (Minor->Major)   Z=2.0789e+01      0.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value Database
# 16                NaN                r           0.121943  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Increasing Trend (Minor->Major): stat=Z=2.0789e+01, p=0.0, e=0.1219431005145353, e_symbol=r
#                                Synergy_Score       Test_Type  \
# 30  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 31  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 32  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 30         All Groups   H=1.0964e+03  8.281342e-239                NaN
# 31     Major vs Minor         Dunn Z            NaN       9.491539e-31
# 32  Major vs Moderate         Dunn Z            NaN       2.636158e-11
#
#    Effect_Size_Type  Effect_Size_Value  Database
# 30    Eta-Squared H           0.017479  DrugBank
# 31    Cliff's Delta           0.226887  DrugBank
# 32    Cliff's Delta           0.108966  DrugBank
#                                Synergy_Score            Test_Type  \
# 35  All Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 35  Decreasing Trend (Major->Minor)  Z=-3.2245e+01      1.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value  Database
# 35                NaN                r          -0.128746  DrugBank
# Retrived for DrugBank, All Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-3.2245e+01, p=1.0, e=-0.1287458580388428, e_symbol=r
#                                Synergy_Score       Test_Type  \
# 12  All Reactome Pathways Jaccard Similarity  Kruskal-Wallis
# 13  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
# 14  All Reactome Pathways Jaccard Similarity   Dunn Post-Hoc
#
#            Comparison Test_Statistic        P_value  P_value_Corrected  \
# 12         All Groups   H=7.6788e+02  1.809712e-167                NaN
# 13     Major vs Minor         Dunn Z            NaN       1.352075e-25
# 14  Major vs Moderate         Dunn Z            NaN       9.079921e-22
#
#    Effect_Size_Type  Effect_Size_Value Database
# 12    Eta-Squared H           0.026421  DDInter
# 13    Cliff's Delta           0.049278  DDInter
# 14    Cliff's Delta           0.223512  DDInter
#                                Synergy_Score            Test_Type  \
# 17  All Reactome Pathways Jaccard Similarity  Jonckheere-Terpstra
#
#                          Comparison Test_Statistic  P_value  \
# 17  Decreasing Trend (Major->Minor)  Z=-2.0789e+01      1.0
#
#     P_value_Corrected Effect_Size_Type  Effect_Size_Value Database
# 17                NaN                r          -0.121943  DDInter
# Retrived for DDInter, All Reactome Pathways Jaccard Similarity, Jonckheere-Terpstra, Decreasing Trend (Major->Minor): stat=Z=-2.0789e+01, p=1.0, e=-0.1219431005145353, e_symbol=r
# \begin{table}[htbp]
# \centering
# \small
# \caption{\textbf{Drug target and pathway overlap toxicity analysis}. Results for statistical analysis of drug targets and pathway overlap correlated with toxicity categories. Each section refers to a different Jaccard Similarity metric. The first section computed the overlap between the sets of drug targets in a given drug combination, the second the sets of pathways, and the third the sets of pathways when restricted to the lowest level of Reactome. The results for the Kruskal-Wallis, Dunn with Bonferroni correction, and Jonckheere-Terpstra tests are included for both the DrugBank and DDInter datasets. The Jonckheere-Terpestra Increasing Toxicity test assesses whether the distribution of the Jaccard Similarity increases when toxicity categories become more severe, while the Jonckheere-Terpstra Decreasing Toxicity test evaluates if the Jaccard Similarity distributions increase when the toxicity categories decrease in severity.}
# \label{tab:s_targ_tox}
# \vspace{0.5em}
# \resizebox{\textwidth}{!}{
# \scriptsize
# \begin{tabular}{ll|rr|rr}
# \toprule
# \textbf{Overlap Metric} & \textbf{Test} & \multicolumn{2}{c|}{\textbf{DrugBank}} & \multicolumn{2}{c}{\textbf{DDInter}} \\
# \textbf{Score} &  & \textbf{Test Statistic} & \textbf{P-value (Effect Size)} & \textbf{Test Statistic} & \textbf{P-value (Effect Size)} \\
# \midrule
# \multirow{6}{*}{\textbf{Drug Target Jaccard Similarity}} & Kruskal-Wallis & $1.533 \times 10^{2}$ & $5.254 \times 10^{-34}$ ($\mathbf{\eta^2}=+0.002$) & $1.565 \times 10^{2}$ & $1.053 \times 10^{-34}$ ($\mathbf{\eta^2}=+0.005$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.036$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.110$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.014$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.039$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.022$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=+0.067$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $4.782$ & $8.687 \times 10^{-7}$ ($\mathbf{r}=+0.019$) & $5.679$ & $6.787 \times 10^{-9}$ ($\mathbf{r}=+0.033$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-4.782$ & $1.000$ ($\mathbf{r}=-0.019$) & $-5.679$ & $1.000$ ($\mathbf{r}=-0.033$) \\
# \midrule
# \multirow{6}{*}{\textbf{Lowest Reactome Pathways Jaccard Similarity}} & Kruskal-Wallis & $1.085 \times 10^{3}$ & $2.790 \times 10^{-236}$ ($\mathbf{\eta^2}=+0.017$) & $1.584 \times 10^{3}$ & $0.000$ ($\mathbf{\eta^2}=+0.055$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.193$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.081$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.097$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.287$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.086$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=-0.266$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $2.789 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.111$) & $2.710 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.159$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-2.789 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.111$) & $-2.710 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.159$) \\
# \midrule
# \multirow{6}{*}{\textbf{All Reactome Pathways Jaccard Similarity}} & Kruskal-Wallis & $1.096 \times 10^{3}$ & $8.281 \times 10^{-239}$ ($\mathbf{\eta^2}=+0.017$) & $7.679 \times 10^{2}$ & $1.810 \times 10^{-167}$ ($\mathbf{\eta^2}=+0.026$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.227$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.049$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.109$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.224$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.112$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=-0.226$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $3.224 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.129$) & $2.079 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.122$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-3.224 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.129$) & $-2.079 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.122$) \\
# \bottomrule
# \end{tabular}
# }
# \end{table}
# Success! LaTeX table saved to results/pathway_syntox_analysis/pathway_statistical_summary_table.tex
# \begin{table}[htbp]
# \centering
# \small
# \caption{\textbf{Drug target and pathway overlap toxicity analysis}. Results for statistical analysis of drug targets and pathway overlap correlated with toxicity categories. Each section refers to a different Jaccard Similarity metric. The first section computed the overlap between the sets of drug targets in a given drug combination, the second the sets of pathways, and the third the sets of pathways when restricted to the lowest level of Reactome. The results for the Kruskal-Wallis, Dunn with Bonferroni correction, and Jonckheere-Terpstra tests are included for both the DrugBank and DDInter datasets. The Jonckheere-Terpestra Increasing Toxicity test assesses whether the distribution of the Jaccard Similarity increases when toxicity categories become more severe, while the Jonckheere-Terpstra Decreasing Toxicity test evaluates if the Jaccard Similarity distributions increase when the toxicity categories decrease in severity.}
# \label{tab:s_targ_tox}
# \vspace{0.5em}
# \resizebox{\textwidth}{!}{
# \scriptsize
# \begin{tabular}{ll|rr|rr}
# \toprule
# \textbf{Overlap Metric} & \textbf{Test} & \multicolumn{2}{c|}{\textbf{DrugBank}} & \multicolumn{2}{c}{\textbf{DDInter}} \\
# \textbf{Score} &  & \textbf{Test Statistic} & \textbf{P-value (Effect Size)} & \textbf{Test Statistic} & \textbf{P-value (Effect Size)} \\
# \midrule
# \multirow{6}{*}{\textbf{Drug Target Jaccard Similarity}} & Kruskal-Wallis & $1.533 \times 10^{2}$ & $5.254 \times 10^{-34}$ ($\mathbf{\eta^2}=+0.002$) & $1.565 \times 10^{2}$ & $1.053 \times 10^{-34}$ ($\mathbf{\eta^2}=+0.005$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.036$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.110$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.014$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.039$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.022$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=+0.067$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $4.782$ & $8.687 \times 10^{-7}$ ($\mathbf{r}=+0.019$) & $5.679$ & $6.787 \times 10^{-9}$ ($\mathbf{r}=+0.033$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-4.782$ & $1.000$ ($\mathbf{r}=-0.019$) & $-5.679$ & $1.000$ ($\mathbf{r}=-0.033$) \\
# \midrule
# \multirow{6}{*}{\textbf{Lowest Reactome Pathways Jaccard Similarity}} & Kruskal-Wallis & $1.085 \times 10^{3}$ & $2.790 \times 10^{-236}$ ($\mathbf{\eta^2}=+0.017$) & $1.584 \times 10^{3}$ & $0.000$ ($\mathbf{\eta^2}=+0.055$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.193$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.081$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.097$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.287$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.086$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=-0.266$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $2.789 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.111$) & $2.710 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.159$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-2.789 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.111$) & $-2.710 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.159$) \\
# \midrule
# \multirow{6}{*}{\textbf{All Reactome Pathways Jaccard Similarity}} & Kruskal-Wallis & $1.096 \times 10^{3}$ & $8.281 \times 10^{-239}$ ($\mathbf{\eta^2}=+0.017$) & $7.679 \times 10^{2}$ & $1.810 \times 10^{-167}$ ($\mathbf{\eta^2}=+0.026$) \\
#  & Dunn: Major/Minor & - & $9.492 \times 10^{-31}$ ($\mathbf{\delta}=+0.227$) & - & $1.352 \times 10^{-25}$ ($\mathbf{\delta}=+0.049$) \\
#  & Dunn: Major/Moderate & - & $2.636 \times 10^{-11}$ ($\mathbf{\delta}=+0.109$) & - & $9.080 \times 10^{-22}$ ($\mathbf{\delta}=+0.224$) \\
#  & Dunn: Moderate/Minor & - & $1.684 \times 10^{-10}$ ($\mathbf{\delta}=+0.112$) & - & $5.719 \times 10^{-12}$ ($\mathbf{\delta}=-0.226$) \\
#  & Jonckheere-Terpstra: Increasing Toxicity & $3.224 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.129$) & $2.079 \times 10^{1}$ & $0.000$ ($\mathbf{r}=+0.122$) \\
#  & Jonckheere-Terpstra: Decreasing Toxicity & $-3.224 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.129$) & $-2.079 \times 10^{1}$ & $1.000$ ($\mathbf{r}=-0.122$) \\
# \bottomrule
# \end{tabular}
# }
# \end{table}
